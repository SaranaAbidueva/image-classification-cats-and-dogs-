# %%
import numpy as np
import pandas as pd 
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, load_img
import matplotlib.pyplot as plt

# %% [markdown]
# # Загрузка и просмотр данных

# %%
import os #чтение файлов и структуры директорий
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'model.h5', 'sampleSubmission.csv', 'test1', 'train', 'нейронка.ipynb']

# %%
images = os.listdir("train/train")
categories = []
for image in images:
    category = image.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': images,
    'category': categories
})
df.head()
# Out:
#        filename  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %% [markdown]
# данные упорядочены в алфавитном порядке, нужно будет перемешать

# %%
df['category'].value_counts().plot.bar()

# %% [markdown]
# видно, что классы распределены поровну
#
# посмотрим картинку-пример

# %%
import random
from keras.preprocessing.image import load_img
sample_name = random.choice(images)
image = load_img("train/train/"+sample_name)
plt.imshow(image)

# %% [markdown]
# # Предобработка данных
# произведем нормализацию;
# заменила название категорий на cat и dog так как у генератора class_mode="categorical"
#
# разбила размеченные данные на тренировочное и валидационные множества, добавила индексы

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})
train_df, validate_df = train_test_split(df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
validate_df['category'].value_counts().plot.bar()

# %%
train_df['category'].value_counts().plot.bar()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

batch_size = 15 # количество тренировочных изображений для обработки перед обновлением параметров модели
IMAGE_SIZE = (150, 150)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
FAST_RUN = False

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    directory="train/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "train/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "train/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# Посмотрим работу генератора

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Построение модели

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 - 2 класса

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 72, 72, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 34, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36992)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18940416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 19,037,634
# Trainable params: 19,036,162
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=7)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# # Обучение модели

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-63cb34b6e89a>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 1333/1333 [==============================] - 1338s 1s/step - loss: 0.7497 - accuracy: 0.6318 - val_loss: 0.5773 - val_accuracy: 0.7237
# Epoch 2/50
# 1333/1333 [==============================] - 1341s 1s/step - loss: 0.5588 - accuracy: 0.7231 - val_loss: 0.5125 - val_accuracy: 0.7479
# Epoch 3/50
# 1333/1333 [==============================] - 1336s 1s/step - loss: 0.4983 - accuracy: 0.7608 - val_loss: 0.4488 - val_accuracy: 0.7998
# Epoch 4/50
# 1333/1333 [==============================] - 1341s 1s/step - loss: 0.4639 - accuracy: 0.7851 - val_loss: 0.4167 - val_accuracy: 0.8094
# Epoch 5/50
# 1333/1333 [==============================] - 1326s 994ms/step - loss: 0.4324 - accuracy: 0.8045 - val_loss: 0.4681 - val_accuracy: 0.7918
# Epoch 6/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8185
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.4055 - accuracy: 0.8185 - val_loss: 0.5976 - val_accuracy: 0.7495
# Epoch 7/50
# 1333/1333 [==============================] - 1329s 997ms/step - loss: 0.3609 - accuracy: 0.8405 - val_loss: 0.3755 - val_accuracy: 0.8368
# Epoch 8/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3444 - accuracy: 0.8497 - val_loss: 0.3787 - val_accuracy: 0.8320
# Epoch 9/50
# 1333/1333 [==============================] - 1327s 995ms/step - loss: 0.3466 - accuracy: 0.8489 - val_loss: 0.3574 - val_accuracy: 0.8456
# Epoch 10/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3374 - accuracy: 0.8560 - val_loss: 0.2762 - val_accuracy: 0.8803
# Epoch 11/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3250 - accuracy: 0.8616 - val_loss: 0.3072 - val_accuracy: 0.8709
# Epoch 12/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3213 - accuracy: 0.8622 - val_loss: 0.2962 - val_accuracy: 0.8853
# Epoch 13/50
# 1333/1333 [==============================] - 1336s 1s/step - loss: 0.3195 - accuracy: 0.8618 - val_loss: 0.2890 - val_accuracy: 0.8867
# Epoch 14/50
# 1333/1333 [==============================] - 1329s 997ms/step - loss: 0.3140 - accuracy: 0.8676 - val_loss: 0.3684 - val_accuracy: 0.8557
# Epoch 15/50
# 1333/1333 [==============================] - 1330s 998ms/step - loss: 0.3125 - accuracy: 0.8667 - val_loss: 0.2745 - val_accuracy: 0.8979
# Epoch 16/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3005 - accuracy: 0.8735 - val_loss: 0.2504 - val_accuracy: 0.8995
# Epoch 17/50
# 1333/1333 [==============================] - 1329s 997ms/step - loss: 0.3002 - accuracy: 0.8738 - val_loss: 0.2422 - val_accuracy: 0.9081
# Epoch 18/50
# 1333/1333 [==============================] - 1328s 996ms/step - loss: 0.3048 - accuracy: 0.8688 - val_loss: 0.2869 - val_accuracy: 0.8923
# Epoch 19/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0